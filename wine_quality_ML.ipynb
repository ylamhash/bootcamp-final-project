# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv("winequality-white.csv",  sep = ';')
raw_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
train_df = raw_df.iloc[:4000]
train_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 3995            8.0              0.37         0.31             4.7      0.038
# 3996            6.7              0.28         0.34             8.9      0.048
# 3997            6.0              0.26         0.29             3.1      0.041
# 3998            6.4              0.24         0.49             5.8      0.053
# 3999            6.4              0.24         0.49             5.8      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 3995                  3.0                 127.0  0.99186  2.90       0.72
# 3996                 32.0                 111.0  0.99455  3.25       0.54
# 3997                 37.0                 144.0  0.98944  3.22       0.39
# 3998                 25.0                 120.0  0.99420  3.01       0.98
# 3999                 25.0                 120.0  0.99420  3.01       0.98
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 3995     12.1        5
# 3996     11.0        7
# 3997     12.8        7
# 3998     10.5        6
# 3999     10.5        6
#
# [4000 rows x 12 columns]

# %%
train_df.to_csv('train_dataset.csv', index = False)

# %%
validation_df = raw_df.iloc[4000:4899]
validation_df = validation_df.drop(columns=['quality'])
validation_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4000            6.4              0.24         0.49             5.8      0.053
# 4001            6.4              0.25         0.57             1.0      0.062
# 4002            6.1              0.25         0.48            15.8      0.052
# 4003            6.8              0.14         0.35             1.5      0.047
# 4004            6.5              0.38         0.26             5.2      0.042
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4000                 25.0                 120.0  0.99420  3.01       0.98
# 4001                 21.0                 122.0  0.99238  3.00       0.40
# 4002                 25.0                  94.0  0.99782  3.07       0.45
# 4003                 40.0                 117.0  0.99111  3.07       0.72
# 4004                 33.0                 112.0  0.99067  3.06       0.50
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 4000     10.5
# 4001      9.5
# 4002      9.2
# 4003     11.1
# 4004     12.3
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [898 rows x 11 columns]

# %%
validation_df.to_csv('validation_dataset.csv', index = False)

# %%
training_df = pd.read_csv("train_dataset.csv")
training_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 3995            8.0              0.37         0.31             4.7      0.038
# 3996            6.7              0.28         0.34             8.9      0.048
# 3997            6.0              0.26         0.29             3.1      0.041
# 3998            6.4              0.24         0.49             5.8      0.053
# 3999            6.4              0.24         0.49             5.8      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 3995                  3.0                 127.0  0.99186  2.90       0.72
# 3996                 32.0                 111.0  0.99455  3.25       0.54
# 3997                 37.0                 144.0  0.98944  3.22       0.39
# 3998                 25.0                 120.0  0.99420  3.01       0.98
# 3999                 25.0                 120.0  0.99420  3.01       0.98
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 3995     12.1        5
# 3996     11.0        7
# 3997     12.8        7
# 3998     10.5        6
# 3999     10.5        6
#
# [4000 rows x 12 columns]

# %%
training_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4000.000000       4000.000000  4000.000000     4000.000000
# mean        6.957212          0.275818     0.341097        6.364063
# std         0.844625          0.100184     0.122548        5.091631
# min         4.200000          0.080000     0.000000        0.600000
# 25%         6.400000          0.210000     0.270000        1.700000
# 50%         6.900000          0.260000     0.320000        5.200000
# 75%         7.400000          0.320000     0.400000        9.800000
# max        14.200000          1.005000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4000.000000          4000.000000           4000.000000  4000.000000
# mean      0.045631            35.574000            140.488625     0.994188
# std       0.021960            16.910471             43.264248     0.002993
# min       0.009000             2.000000              9.000000     0.987130
# 25%       0.036000            24.000000            109.000000     0.991880
# 50%       0.043000            34.000000            137.000000     0.993900
# 75%       0.050000            46.000000            170.000000     0.996258
# max       0.346000           146.500000            366.500000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4000.000000  4000.000000  4000.000000  4000.000000
# mean      3.191968     0.489238    10.461225     5.879750
# std       0.152897     0.114696     1.215563     0.909943
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.400000     5.000000
# 50%       3.180000     0.470000    10.300000     6.000000
# 75%       3.290000     0.550000    11.300000     6.000000
# max       3.820000     1.060000    14.200000     9.000000

# %%
quality_score_df = training_df['quality'].value_counts().rename_axis('quality score').reset_index(name='counts')
quality_score_df
# Out:
#    quality score  counts
# 0              6    1717
# 1              5    1214
# 2              7     747
# 3              8     156
# 4              4     142
# 5              3      19
# 6              9       5

# %%
plt.style.use('ggplot')
plt.bar(quality_score_df['quality score'], quality_score_df['counts'], color='#86bf91')
plt.xlabel("Quality Rating")
plt.ylabel("Number of Ratings")
plt.title("White Wine Quality Ratings")
# Out:
# Text(0.5, 1.0, 'White Wine Quality Ratings')

# %%
labels = quality_score_df['quality score'].to_list()
sizes = quality_score_df['counts'].to_list()
colors = ['#A569BD', '#7FB3D5', '#76D7C4', '#F1948A', '#F7DC6F', '#E59866', '#AAB7B8']
explode = (0.1, 0, 0, 0, 0, 0, 0)
fig, ax1 = plt.subplots(figsize = (12, 6)) 
ax1.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Quality Score Percentages")
plt.tight_layout()
plt.show()

# %%
#maybe we can say a rating >= 7 is considered a good wine?

# %%
X = training_df.drop("quality", axis=1)
y = training_df["quality"]
print(X.shape, y.shape)
# Out:
# (4000, 11) (4000,)
